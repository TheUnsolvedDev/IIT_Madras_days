# %% [markdown]
# # Testing of Algorithms for different scenarios

# %%
from main import *
from environment import *
from solver import *
from utils import *

# %%
def plot_data(data,x_label,y_label,title=None):
    plt.plot(range(len(data)),data)
    plt.xlabel(x_label)
    plt.ylabel(y_label)
    plt.title(title)
    plt.show()

# %%
cases = ['sharpen', 'log', 'tikhonov']
for case in cases:
    algorithm = Algorithm()
    algorithm.init()    
    rank_history = algorithm.simulate(case)
    plot_data(rank_history,'steps','rank',title=case)
# Out:
# steps: 0 	action taken: 10 0 	rank: 1
# steps: 20 	action taken: 16 9 	rank: 19
# steps: 40 	action taken: 26 6 	rank: 27
# steps: 60 	action taken: 29 16 	rank: 28
# steps: 80 	action taken: 29 19 	rank: 29
# steps: 100 	action taken: 29 27 	rank: 29
# steps: 0 	action taken: 10 0 	rank: 1
# steps: 20 	action taken: 29 24 	rank: 19
# steps: 40 	action taken: 6 5 	rank: 26
# steps: 60 	action taken: 15 6 	rank: 27
# steps: 80 	action taken: 10 0 	rank: 29
# steps: 100 	action taken: 16 7 	rank: 29
# steps: 0 	action taken: 10 0 	rank: 1
# steps: 20 	action taken: 13 11 	rank: 14
# steps: 40 	action taken: 16 15 	rank: 21
# steps: 60 	action taken: 24 12 	rank: 25
# steps: 80 	action taken: 6 4 	rank: 28
# steps: 100 	action taken: 4 3 	rank: 29
