# %%
import jax
import numpy as np
import jax.numpy as jnp
import gymnasium as gym
import flax
from flax.training.train_state import TrainState
import optax
import functools
import matplotlib.pyplot as plt
import tqdm

# %%
ALPHA = 0.001
GAMMA = 0.99
BATCH_SIZE = 64
CAPACITY = 20000

# %%
def smooth_rewards(rewards, window_size=10):
    smoothed_rewards = np.zeros_like(rewards)
    for i in range(len(rewards)):
        window_start = max(0, i - window_size // 2)
        window_end = min(len(rewards), i + window_size // 2 + 1)
        smoothed_rewards[i] = np.mean(rewards[window_start:window_end])
    return smoothed_rewards


def plot_data(mean, std):
    x = range(len(mean))

    plt.plot(x, mean, color='blue', label='Mean')
    plt.plot(x, smooth_rewards(mean), color='orange', label='smoothed')
    plt.fill_between(x, mean - std, mean + std, color='blue',
                     alpha=0.3, label='Mean ± Std')

    plt.xlabel('Steps')
    plt.ylabel('Rewards')
    plt.title('Mean with Standard Deviation')
    plt.legend()
    plt.grid(True)
    plt.show()
    
def linear_schedule(start_e: float, end_e: float, duration: int, t: int):
    slope = (end_e - start_e) / duration
    return max(slope * t + start_e, end_e)

# %%
class ValueNetworkMean(flax.linen.Module):
    action_dim: int

    @flax.linen.compact
    def __call__(self, x: jnp.ndarray):
        x = flax.linen.Dense(16)(x)
        x = flax.linen.leaky_relu(x)
        value_stream = flax.linen.Dense(1)(x)
        advantage_stream = flax.linen.Dense(self.action_dim)(x)
        q_values = value_stream + \
            (advantage_stream - jnp.mean(advantage_stream, axis=-1, keepdims=True))

        return q_values


class ValueNetworkMax(flax.linen.Module):
    action_dim: int

    @flax.linen.compact
    def __call__(self, x: jnp.ndarray):
        x = flax.linen.Dense(16)(x)
        x = flax.linen.leaky_relu(x)
        value_stream = flax.linen.Dense(1)(x)
        advantage_stream = flax.linen.Dense(self.action_dim)(x)
        q_values = value_stream + \
            (advantage_stream - jnp.max(advantage_stream, axis=-1, keepdims=True))

        return q_values

# %%
class ReplayBuffer:
    def __init__(self, capacity):
        self.capacity = capacity
        self.buffer = []
        self.position = 0

    def push(self, transition):
        if len(self.buffer) < self.capacity:
            self.buffer.append(transition)
        else:
            self.buffer[self.position] = transition
        self.position = (self.position + 1) % self.capacity

    def sample(self, batch_size):
        return np.random.choice(len(self.buffer), size=(batch_size,))

    def get_batch(self, indices):
        states, actions, rewards, next_states, dones = zip(
            *[self.buffer[i] for i in indices])
        states = jnp.array(states)
        actions = jnp.array(actions)
        rewards = jnp.array(rewards)
        next_states = jnp.array(next_states)
        dones = jnp.array(dones)
        return states, actions, rewards, next_states, dones

# %%
class TrainState(TrainState):
    target_params: flax.core.FrozenDict

# %%
class DuelingDQNMean:
    def __init__(self, env, num_actions, observation_shape, seed=0) -> None:
        self.seed = seed
        self.rng = jax.random.PRNGKey(seed)
        self.num_actions = num_actions
        self.observation_shape = observation_shape
        self.env = env

        self.value = ValueNetworkMean(num_actions)
        self.value_state = TrainState.create(
            apply_fn=self.value.apply,
            params=self.value.init(self.rng, jnp.ones(observation_shape)),
            target_params=self.value.init(
                self.rng, jnp.ones(observation_shape)),
            tx=optax.adam(learning_rate=ALPHA)
        )
        self.value.apply = jax.jit(self.value.apply)
        self.value_state = self.value_state.replace(target_params=optax.incremental_update(
            self.value_state.params, self.value_state.target_params, 0.9))
        self.replay_buffer = ReplayBuffer(CAPACITY)
        self.counter = 1

    def sample(self, state, epsilon=0.1):
        if np.random.uniform() < epsilon:
            return np.random.randint(0, self.num_actions)
        q_values = self.value.apply(self.value_state.params, state)
        action = np.array(q_values).argmax(axis = -1)[0]
        return action

    def update(self, states, actions, rewards, next_states,  dones):
        value_next_target = self.value.apply(
            self.value_state.target_params, next_states)
        value_next_target = jnp.max(value_next_target, axis=-1)
        next_q_value = (rewards + (1 - dones) * GAMMA * value_next_target)

        @jax.jit
        def mse_loss(params):
            value_pred = self.value.apply(params, states)
            value_pred = value_pred[jnp.arange(
                value_pred.shape[0]), actions.squeeze()]
            return ((jax.lax.stop_gradient(next_q_value) - value_pred) ** 2).mean()

        loss_value, grads = jax.value_and_grad(
            mse_loss)(self.value_state.params)
        self.value_state = self.value_state.apply_gradients(grads=grads)
        return loss_value

    def train_single_step(self):
        state = self.env.reset(seed=self.seed)[0]
        key = self.rng
        epsilon = linear_schedule(
            start_e=1, end_e=0.05, duration=500, t=0 if self.counter < 50 else self.counter)

        episode_loss, episode_rewards = 0, 0
        for _ in range(500):
            action = self.sample(np.expand_dims(state, axis=0), epsilon)
            next_state, reward, done, truncated, info = self.env.step(action)
            self.replay_buffer.push(
                [state, action, reward, next_state, done or truncated])
            state = next_state
            episode_rewards += reward

            if truncated or done:
                break

            if len(self.replay_buffer.buffer) > 128:
                indices = self.replay_buffer.sample(BATCH_SIZE)
                states, actions, rewards, next_states, dones = self.replay_buffer.get_batch(
                    indices)
                loss_values = self.update(
                    states, actions, rewards, next_states,  dones)
                episode_loss += loss_values

        self.counter += 1
        return episode_loss,episode_rewards

# %%
class Simulation:
    def __init__(self, env_name, algorithm) -> None:
        self.env_name = env_name
        self.algorithm = algorithm
        self.env = gym.make(self.env_name)
        self.num_actions = self.env.action_space.n
        self.observation_shape = self.env.observation_space.shape

    def train(self, episodes=1000):
        self.losses, self.rewards = np.zeros(
            (5, episodes)), np.zeros((5, episodes))

        for seed in range(5):
            self.algo = self.algorithm(
                self.env, self.num_actions, self.observation_shape, seed=seed)
            for ep in tqdm.tqdm(range(1, episodes+1)):
                loss, reward = self.algo.train_single_step()
                self.losses[seed][ep-1] = loss
                self.rewards[seed][ep-1] = reward

# %%
cartpole_mean_value = Simulation('CartPole-v1', algorithm=DuelingDQNMean)
cartpole_mean_value.train()
# Out:
#   1%|          | 9/1000 [00:10<18:30,  1.12s/it]
# ---------------------------------------------------------------------------
# KeyboardInterrupt                         Traceback (most recent call last)
# Cell In[9], line 2
#       1 cartpole_mean_value = Simulation('CartPole-v1', algorithm=DuelingDQNMean)
# ----> 2 cartpole_mean_value.train()
#
# Cell In[8], line 17, in Simulation.train(self, episodes)
#      14 self.algo = self.algorithm(
#      15     self.env, self.num_actions, self.observation_shape, seed=seed)
#      16 for ep in tqdm.tqdm(range(1, episodes+1)):
# ---> 17     loss, reward = self.algo.train_single_step()
#      18     self.losses[seed][ep-1] = loss
#      19     self.rewards[seed][ep-1] = reward
#
# Cell In[7], line 70, in DuelingDQNMean.train_single_step(self)
#      67         indices = self.replay_buffer.sample(BATCH_SIZE)
#      68         states, actions, rewards, next_states, dones = self.replay_buffer.get_batch(
#      69             indices)
# ---> 70         loss_values = self.update(
#      71             states, actions, rewards, next_states,  dones)
#      72         episode_loss += loss_values
#      74 self.counter += 1
#
# Cell In[7], line 43, in DuelingDQNMean.update(self, states, actions, rewards, next_states, dones)
#      39     value_pred = value_pred[jnp.arange(
#      40         value_pred.shape[0]), actions.squeeze()]
#      41     return ((jax.lax.stop_gradient(next_q_value) - value_pred) ** 2).mean()
# ---> 43 loss_value, grads = jax.value_and_grad(
#      44     mse_loss)(self.value_state.params)
#      45 self.value_state = self.value_state.apply_gradients(grads=grads)
#      46 return loss_value
#
#     [... skipping hidden 1 frame]
#
# File ~/.local/lib/python3.11/site-packages/jax/_src/api.py:745, in value_and_grad.<locals>.value_and_grad_f(*args, **kwargs)
#     743   _check_input_dtype_grad(holomorphic, allow_int, leaf)
#     744 if not has_aux:
# --> 745   ans, vjp_py = _vjp(f_partial, *dyn_args, reduce_axes=reduce_axes)
#     746 else:
#     747   ans, vjp_py, aux = _vjp(
#     748       f_partial, *dyn_args, has_aux=True, reduce_axes=reduce_axes)
#
# File ~/.local/lib/python3.11/site-packages/jax/_src/api.py:2238, in _vjp(fun, has_aux, reduce_axes, *primals)
#    2236 if not has_aux:
#    2237   flat_fun, out_tree = flatten_fun_nokwargs(fun, in_tree)
# -> 2238   out_primal, out_vjp = ad.vjp(
#    2239       flat_fun, primals_flat, reduce_axes=reduce_axes)
#    2240   out_tree = out_tree()
#    2241 else:
#
# File ~/.local/lib/python3.11/site-packages/jax/_src/interpreters/ad.py:143, in vjp(traceable, primals, has_aux, reduce_axes)
#     141 def vjp(traceable, primals, has_aux=False, reduce_axes=()):
#     142   if not has_aux:
# --> 143     out_primals, pvals, jaxpr, consts = linearize(traceable, *primals)
#     144   else:
#     145     out_primals, pvals, jaxpr, consts, aux = linearize(traceable, *primals, has_aux=True)
#
# File ~/.local/lib/python3.11/site-packages/jax/_src/interpreters/ad.py:132, in linearize(traceable, *primals, **kwargs)
#     130 _, in_tree = tree_flatten(((primals, primals), {}))
#     131 jvpfun_flat, out_tree = flatten_fun(jvpfun, in_tree)
# --> 132 jaxpr, out_pvals, consts = pe.trace_to_jaxpr_nounits(jvpfun_flat, in_pvals)
#     133 out_primals_pvals, out_tangents_pvals = tree_unflatten(out_tree(), out_pvals)
#     134 assert all(out_primal_pval.is_known() for out_primal_pval in out_primals_pvals)
#
# File ~/.local/lib/python3.11/site-packages/jax/_src/profiler.py:336, in annotate_function.<locals>.wrapper(*args, **kwargs)
#     333 @wraps(func)
#     334 def wrapper(*args, **kwargs):
#     335   with TraceAnnotation(name, **decorator_kwargs):
# --> 336     return func(*args, **kwargs)
#     337   return wrapper
#
# File ~/.local/lib/python3.11/site-packages/jax/_src/interpreters/partial_eval.py:774, in trace_to_jaxpr_nounits(fun, pvals, instantiate)
#     772 with core.new_main(JaxprTrace, name_stack=current_name_stack) as main:
#     773   fun = trace_to_subjaxpr_nounits(fun, main, instantiate)
# --> 774   jaxpr, (out_pvals, consts, env) = fun.call_wrapped(pvals)
#     775   assert not env
#     776   del main, fun, env
#
# File ~/.local/lib/python3.11/site-packages/jax/_src/linear_util.py:192, in WrappedFun.call_wrapped(self, *args, **kwargs)
#     189 gen = gen_static_args = out_store = None
#     191 try:
# --> 192   ans = self.f(*args, **dict(self.params, **kwargs))
#     193 except:
#     194   # Some transformations yield from inside context managers, so we have to
#     195   # interrupt them before reraising the exception. Otherwise they will only
#     196   # get garbage-collected at some later time, running their cleanup tasks
#     197   # only after this exception is handled, which can corrupt the global
#     198   # state.
#     199   while stack:
#
#     [... skipping hidden 1 frame]
#
# File ~/.local/lib/python3.11/site-packages/jax/_src/pjit.py:248, in _cpp_pjit.<locals>.cache_miss(*args, **kwargs)
#     246 @api_boundary
#     247 def cache_miss(*args, **kwargs):
# --> 248   outs, out_flat, out_tree, args_flat, jaxpr, attrs_tracked = _python_pjit_helper(
#     249       fun, infer_params_fn, *args, **kwargs)
#     250   executable = _read_most_recent_pjit_call_executable(jaxpr)
#     251   maybe_fastpath_data = _get_fastpath_data(
#     252       executable, out_tree, args_flat, out_flat, attrs_tracked)
#
# File ~/.local/lib/python3.11/site-packages/jax/_src/pjit.py:143, in _python_pjit_helper(fun, infer_params_fn, *args, **kwargs)
#     141   args_flat = [*init_states, *args_flat]
#     142 try:
# --> 143   out_flat = pjit_p.bind(*args_flat, **params)
#     144 except pxla.DeviceAssignmentMismatchError as e:
#     145   fails, = e.args
#
# File ~/.local/lib/python3.11/site-packages/jax/_src/core.py:2727, in AxisPrimitive.bind(self, *args, **params)
#    2723 axis_main = max((axis_frame(a).main_trace for a in used_axis_names(self, params)),
#    2724                 default=None, key=lambda t: getattr(t, 'level', -1))
#    2725 top_trace = (top_trace if not axis_main or axis_main.level < top_trace.level
#    2726              else axis_main.with_cur_sublevel())
# -> 2727 return self.bind_with_trace(top_trace, args, params)
#
# File ~/.local/lib/python3.11/site-packages/jax/_src/core.py:423, in Primitive.bind_with_trace(self, trace, args, params)
#     422 def bind_with_trace(self, trace, args, params):
# --> 423   out = trace.process_primitive(self, map(trace.full_raise, args), params)
#     424   return map(full_lower, out) if self.multiple_results else full_lower(out)
#
# File ~/.local/lib/python3.11/site-packages/jax/_src/interpreters/ad.py:319, in JVPTrace.process_primitive(self, primitive, tracers, params)
#     317   msg = f"Differentiation rule for '{primitive}' not implemented"
#     318   raise NotImplementedError(msg)
# --> 319 primal_out, tangent_out = jvp(primals_in, tangents_in, **params)
#     320 if primitive.multiple_results:
#     321   return [JVPTracer(self, x, t) for x, t in zip(primal_out, tangent_out)]
#
# File ~/.local/lib/python3.11/site-packages/jax/_src/pjit.py:1743, in _pjit_jvp(primals_in, tangents_in, jaxpr, in_shardings, out_shardings, resource_env, donated_invars, name, keep_unused, inline)
#    1741 _filter_zeros_in = partial(_filter_zeros, is_nz_tangents_in)
#    1742 _filter_zeros_out = partial(_filter_zeros, is_nz_tangents_out)
# -> 1743 outputs = pjit_p.bind(
#    1744     *primals_in, *_filter_zeros_in(tangents_in),
#    1745     jaxpr=jaxpr_jvp,
#    1746     in_shardings=(*in_shardings, *_filter_zeros_in(in_shardings)),
#    1747     out_shardings=(*out_shardings, *_filter_zeros_out(out_shardings)),
#    1748     resource_env=resource_env,
#    1749     donated_invars=(*donated_invars, *_filter_zeros_in(donated_invars)),
#    1750     name=name,
#    1751     keep_unused=keep_unused,
#    1752     inline=inline)
#    1754 primals_out, tangents_out = split_list(outputs, [len(jaxpr.jaxpr.outvars)])
#    1755 assert len(primals_out) == len(jaxpr.jaxpr.outvars)
#
# File ~/.local/lib/python3.11/site-packages/jax/_src/core.py:2727, in AxisPrimitive.bind(self, *args, **params)
#    2723 axis_main = max((axis_frame(a).main_trace for a in used_axis_names(self, params)),
#    2724                 default=None, key=lambda t: getattr(t, 'level', -1))
#    2725 top_trace = (top_trace if not axis_main or axis_main.level < top_trace.level
#    2726              else axis_main.with_cur_sublevel())
# -> 2727 return self.bind_with_trace(top_trace, args, params)
#
# File ~/.local/lib/python3.11/site-packages/jax/_src/core.py:423, in Primitive.bind_with_trace(self, trace, args, params)
#     422 def bind_with_trace(self, trace, args, params):
# --> 423   out = trace.process_primitive(self, map(trace.full_raise, args), params)
#     424   return map(full_lower, out) if self.multiple_results else full_lower(out)
#
# File ~/.local/lib/python3.11/site-packages/jax/_src/interpreters/partial_eval.py:212, in JaxprTrace.process_primitive(self, primitive, tracers, params)
#     210 def process_primitive(self, primitive, tracers, params):
#     211   if primitive in custom_partial_eval_rules:
# --> 212     return custom_partial_eval_rules[primitive](self, *tracers, **params)
#     213   else:
#     214     return self.default_process_primitive(primitive, tracers, params)
#
# File ~/.local/lib/python3.11/site-packages/jax/_src/pjit.py:1820, in _pjit_partial_eval(trace, jaxpr, in_shardings, out_shardings, resource_env, donated_invars, name, keep_unused, inline, *in_tracers)
#    1818 # Bind known things to pjit_p.
#    1819 known_inputs = [pv.get_known() for pv in in_pvals if pv.is_known()]
# -> 1820 all_known_outs = pjit_p.bind(*known_inputs, **known_params)
#    1821 all_known_outs = subs_list2(in_fwd, out_fwd, known_inputs, all_known_outs,
#    1822                             all_known_outs)
#    1824 known_out_vals, residual_vals = \
#    1825     split_list(all_known_outs, [len(all_known_outs) - num_residuals])
#
# File ~/.local/lib/python3.11/site-packages/jax/_src/core.py:2727, in AxisPrimitive.bind(self, *args, **params)
#    2723 axis_main = max((axis_frame(a).main_trace for a in used_axis_names(self, params)),
#    2724                 default=None, key=lambda t: getattr(t, 'level', -1))
#    2725 top_trace = (top_trace if not axis_main or axis_main.level < top_trace.level
#    2726              else axis_main.with_cur_sublevel())
# -> 2727 return self.bind_with_trace(top_trace, args, params)
#
# File ~/.local/lib/python3.11/site-packages/jax/_src/core.py:423, in Primitive.bind_with_trace(self, trace, args, params)
#     422 def bind_with_trace(self, trace, args, params):
# --> 423   out = trace.process_primitive(self, map(trace.full_raise, args), params)
#     424   return map(full_lower, out) if self.multiple_results else full_lower(out)
#
# File ~/.local/lib/python3.11/site-packages/jax/_src/core.py:913, in EvalTrace.process_primitive(self, primitive, tracers, params)
#     912 def process_primitive(self, primitive, tracers, params):
# --> 913   return primitive.impl(*tracers, **params)
#
# File ~/.local/lib/python3.11/site-packages/jax/_src/pjit.py:1409, in _pjit_call_impl(jaxpr, in_shardings, out_shardings, resource_env, donated_invars, name, keep_unused, inline, *args)
#    1406 has_explicit_sharding = _pjit_explicit_sharding(
#    1407     in_shardings, out_shardings, None, None)
#    1408 if xla_extension_version >= 226:
# -> 1409   return xc._xla.pjit(
#    1410       name, f, call_impl_cache_miss, [], [], donated_argnums,
#    1411       tree_util.dispatch_registry,
#    1412       pxla.shard_arg if xla_extension_version >= 229 else pxla.temp_shard_arg,  # type: ignore
#    1413       _get_cpp_global_cache(has_explicit_sharding))(*args)
#    1414 else:
#    1415   return xc._xla.pjit(name, f, call_impl_cache_miss, [], [], donated_argnums,  # type: ignore
#    1416                       tree_util.dispatch_registry,
#    1417                       _get_cpp_global_cache(has_explicit_sharding))(*args)
#
# File ~/.local/lib/python3.11/site-packages/jax/_src/pjit.py:1392, in _pjit_call_impl.<locals>.call_impl_cache_miss(*args_, **kwargs_)
#    1391 def call_impl_cache_miss(*args_, **kwargs_):
# -> 1392   out_flat, compiled = _pjit_call_impl_python(
#    1393       *args, jaxpr=jaxpr, in_shardings=in_shardings,
#    1394       out_shardings=out_shardings, resource_env=resource_env,
#    1395       donated_invars=donated_invars, name=name, keep_unused=keep_unused,
#    1396       inline=inline)
#    1397   fastpath_data = _get_fastpath_data(
#    1398       compiled, tree_structure(out_flat), args, out_flat, [])
#    1399   return out_flat, fastpath_data
#
# File ~/.local/lib/python3.11/site-packages/jax/_src/pjit.py:1325, in _pjit_call_impl_python(jaxpr, in_shardings, out_shardings, resource_env, donated_invars, name, keep_unused, inline, *args)
#    1319 global _most_recent_pjit_call_executable
#    1321 in_shardings = _resolve_in_shardings(
#    1322     args, in_shardings, out_shardings,
#    1323     resource_env.physical_mesh if resource_env is not None else None)
# -> 1325 compiled = _pjit_lower(
#    1326     jaxpr, in_shardings, out_shardings, resource_env,
#    1327     donated_invars, name, keep_unused, inline,
#    1328     lowering_parameters=mlir.LoweringParameters()).compile()
#    1329 _most_recent_pjit_call_executable.weak_key_dict[jaxpr] = compiled
#    1330 # This check is expensive so only do it if enable_checks is on.
#
# File ~/.local/lib/python3.11/site-packages/jax/_src/pjit.py:1463, in _pjit_lower(jaxpr, in_shardings, out_shardings, *args, **kwargs)
#    1461 in_shardings = SameDeviceAssignmentTuple(tuple(in_shardings), da)
#    1462 out_shardings = SameDeviceAssignmentTuple(tuple(out_shardings), da)
# -> 1463 return _pjit_lower_cached(jaxpr, in_shardings, out_shardings, *args, **kwargs)
#
# File ~/.local/lib/python3.11/site-packages/jax/_src/pjit.py:1511, in _pjit_lower_cached(jaxpr, sdat_in_shardings, sdat_out_shardings, resource_env, donated_invars, name, keep_unused, inline, lowering_parameters, in_layouts, out_layouts)
#    1505   return pxla.lower_mesh_computation(
#    1506     jaxpr, api_name, name, mesh,
#    1507     in_shardings, out_shardings, donated_invars,
#    1508     True, jaxpr.in_avals, tiling_method=None,
#    1509     lowering_parameters=lowering_parameters)
#    1510 else:
# -> 1511   return pxla.lower_sharding_computation(
#    1512       jaxpr, api_name, name, in_shardings, out_shardings,
#    1513       tuple(donated_invars), tuple(jaxpr.in_avals),
#    1514       keep_unused=keep_unused, inline=inline,
#    1515       devices_from_context=(
#    1516           None if mesh is None or mesh.empty else list(mesh.devices.flat)),
#    1517       lowering_parameters=lowering_parameters, in_layouts=in_layouts,
#    1518       out_layouts=out_layouts)
#
# File ~/.local/lib/python3.11/site-packages/jax/_src/profiler.py:336, in annotate_function.<locals>.wrapper(*args, **kwargs)
#     333 @wraps(func)
#     334 def wrapper(*args, **kwargs):
#     335   with TraceAnnotation(name, **decorator_kwargs):
# --> 336     return func(*args, **kwargs)
#     337   return wrapper
#
# File ~/.local/lib/python3.11/site-packages/jax/_src/interpreters/pxla.py:2038, in lower_sharding_computation(closed_jaxpr, api_name, fun_name, in_shardings, out_shardings, donated_invars, global_in_avals, keep_unused, inline, devices_from_context, lowering_parameters, in_layouts, out_layouts)
#    2034 semantic_out_shardings = SemanticallyEqualShardings(out_shardings)  # type: ignore
#    2035 prim_requires_devices = dispatch.jaxpr_has_prim_requiring_devices(jaxpr)
#    2037 (module, keepalive, host_callbacks, unordered_effects, ordered_effects,
# -> 2038  nreps, tuple_args, shape_poly_state) = _cached_lowering_to_hlo(
#    2039      closed_jaxpr, api_name, fun_name, backend, semantic_in_shardings,
#    2040      semantic_out_shardings, in_layouts, out_layouts, len(da_object),
#    2041      tuple(da_object) if prim_requires_devices else None, donated_invars,
#    2042      name_stack, all_default_mem_kind, lowering_parameters=lowering_parameters)
#    2044 # backend and device_assignment is passed through to MeshExecutable because
#    2045 # if keep_unused=False and all in_shardings are pruned, then there is no way
#    2046 # to get the device_assignment and backend. So pass it to MeshExecutable
#    2047 # because we calculate the device_assignment and backend before in_shardings,
#    2048 # etc are pruned.
#    2049 return MeshComputation(
#    2050     str(name_stack),
#    2051     module,
#    (...)
#    2072     all_default_mem_kind=all_default_mem_kind,
#    2073     all_args_info=all_args_info)
#
# File ~/.local/lib/python3.11/site-packages/jax/_src/interpreters/pxla.py:1879, in _cached_lowering_to_hlo(closed_jaxpr, api_name, fun_name, backend, semantic_in_shardings, semantic_out_shardings, in_layouts, out_layouts, num_devices, device_assignment, donated_invars, name_stack, all_default_mem_kind, lowering_parameters)
#    1874 ordered_effects = list(effects.ordered_effects.filter_in(closed_jaxpr.effects))
#    1876 with dispatch.log_elapsed_time(
#    1877       "Finished jaxpr to MLIR module conversion {fun_name} in {elapsed_time} sec",
#    1878       fun_name=str(name_stack), event=dispatch.JAXPR_TO_MLIR_MODULE_EVENT):
# -> 1879   lowering_result = mlir.lower_jaxpr_to_module(
#    1880       module_name,
#    1881       closed_jaxpr,
#    1882       ordered_effects=ordered_effects,
#    1883       backend_or_name=backend,
#    1884       # Optionally, override the lowering platform
#    1885       platforms=lowering_parameters.platforms or (backend.platform,),
#    1886       axis_context=axis_ctx,
#    1887       name_stack=name_stack,
#    1888       donated_args=donated_invars,
#    1889       replicated_args=replicated_args,
#    1890       arg_shardings=in_mlir_shardings,
#    1891       result_shardings=out_mlir_shardings,
#    1892       in_layouts=in_layouts,
#    1893       out_layouts=out_layouts,
#    1894       arg_names=jaxpr.debug_info and jaxpr.debug_info.arg_names,
#    1895       result_names=jaxpr.debug_info and jaxpr.debug_info.result_paths,
#    1896       num_replicas=nreps,
#    1897       num_partitions=num_partitions,
#    1898       all_default_mem_kind=all_default_mem_kind,
#    1899       lowering_parameters=lowering_parameters)
#    1900 tuple_args = dispatch.should_tuple_args(len(global_in_avals), backend.platform)
#    1901 unordered_effects = list(
#    1902     effects.ordered_effects.filter_not_in(closed_jaxpr.effects))
#
# File ~/.local/lib/python3.11/site-packages/jax/_src/interpreters/mlir.py:953, in lower_jaxpr_to_module(***failed resolving arguments***)
#     948 arg_layouts = (map(_to_xla_layout, in_layouts) if in_layouts is not None
#     949                 else in_layouts)
#     950 result_layouts = (map(_to_xla_layout, out_layouts) if out_layouts is not None
#     951                   else out_layouts)
# --> 953 ctx = ModuleContext(backend_or_name=backend_or_name,
#     954                     platforms=platforms, axis_context=axis_context,
#     955                     keepalives=keepalives,
#     956                     channel_iterator=channel_iter,
#     957                     host_callbacks=host_callbacks,
#     958                     lowering_parameters=lowering_parameters,
#     959                     shape_poly_state=ShapePolyLoweringState(
#     960                         dim_vars, lowering_parameters.platforms))
#     961 with ctx.context, ir.Location.unknown(ctx.context):
#     962   # Remove module name characters that XLA would alter. This ensures that
#     963   # XLA computation preserves the module name.
#     964   attrs = ctx.module.operation.attributes
#
# File ~/.local/lib/python3.11/site-packages/jax/_src/interpreters/mlir.py:636, in ModuleContext.__init__(self, backend_or_name, platforms, axis_context, keepalives, channel_iterator, host_callbacks, lowering_parameters, context, module, ip, symbol_table, cached_primitive_lowerings, traceback_caches, shape_poly_state)
#     617 def __init__(
#     618     self,
#     619     *,
#    (...)
#     633     traceback_caches: None | TracebackCaches = None,
#     634     shape_poly_state = None):
# --> 636   self.context = context or make_ir_context()
#     637   self.module = module or ir.Module.create(loc=ir.Location.unknown(self.context))
#     638   self.ip = ip or ir.InsertionPoint(self.module.body)
#
# File ~/.local/lib/python3.11/site-packages/jax/_src/interpreters/mlir.py:501, in make_ir_context()
#     498 context.enable_multithreading(False)
#     500 dialects.mhlo.register_mhlo_dialect(context)
# --> 501 dialects.chlo.register_dialect(context)
#     502 dialects.hlo.register_dialect(context)
#     503 return context
#
# KeyboardInterrupt:
